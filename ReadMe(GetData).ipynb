# %% [markdown]
# firstly start colab.research.google.com then
# **import bs4 file** (request and bs4 are library file)
# **import request as rq to r**
# then request for the file by **r = rq.get("")**
# then go for r.status_code it means data arrived
# then type r.text and find "title" tag in the given HTML File then type
# **soup = bs4.Beautifulsoup(r.text, "html.parser")**
# enter soup.title it give you title part and if you give** soup.title.get_text()** then it will give you only text which is written in title tag.
#
# class name _3wU53n
#
# then type** soup.findAll('div', attrs=('class','_3wU53n'))** to find particular item
# then make a variable Mydiv and store the above cell
# then make a for loop and run the for loop
#
# for item in Mydivs:
#   print(item.get_text(),end="\n\n")
#
#   then print price and specs the code will be
#   Mydiv = soup.findAll('div', attrs=('class','_1vC4OE _2rQ-NK'))
#   for item in Mydiv:
#   print(item.get_text(),end="\n\n")
#
#   for specs
#   Mydi = soup.findAll('div', attrs=('class','_3ULzGw'))
#   for item in Mydi:
#   print(item.get_text(),end="\n\n")
#
#   then to print all three use code
# for item in Mydivs:
#   print(item.get_text(),end="\n\n")
# for item in Mydiv:
#   print(item.get_text(),end="\n\n")
# for item in Mydi:
#   print(item.get_text(),end="\n\n")
#
#   open api in console.developers.google.com
#   create new project and then go to enable apis and services
#
#   then select youtube api v3
#   and enable it
#   then go credential tab and then click credential and click on option api key and generate it
#   then go to link www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_id}&key={api_key}
#
#   where api key = AIzaSyCCU6hvAvb2kM_ZIKJqv7sXNlRLgoU0Yds
#         channel id = UCj22tfcQrWG7EMEKS0qLeEg
#
#         therefore
#       https://www.googleapis.com/youtube/v3/channels?part=statistics&id=UCj22tfcQrWG7EMEKS0qLeEg&key=AIzaSyCCU6hvAvb2kM_ZIKJqv7sXNlRLgoU0Yds
#
#     do this code in  python
#
#      r  = rq.get("https://www.googleapis.com/youtube/v3/channels?part=statistics&id=UCj22tfcQrWG7EMEKS0qLeEg&key=AIzaSyCCU6hvAvb2kM_ZIKJqv7sXNlRLgoU0Yds")
# r.status_code
# js = r.json()
# js['items'][0]['statistics']['subscriberCount']
